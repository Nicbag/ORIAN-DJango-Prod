# %% [markdown]
# # Yahoo
# ## Informacion

# %%
import yfinance as yf

# Definir el ticker para BYMA
# Nota: Reemplaza 'AAPL.BA' con el ticker correcto para BYMA si es diferente
ticker = yf.Ticker("ETH-USD")

# Obtener información general
info = ticker.info

print(info)
# Out:
# {'twitter': '"https://twitter.com/ethereum"', 'name': 'Ethereum', 'startDate': 1438905600, 'description': 'Ethereum (ETH) is a cryptocurrency . Ethereum has a current supply of 120,362,414.22787383. The last known price of Ethereum is 2,622.2873472 USD and is down -0.94 over the last 24 hours. It is currently trading on 9345 active market(s) with $15,813,901,672.16 traded over the last 24 hours. More information can be found at https://www.ethereum.org/.', 'maxAge': 86400, 'priceHint': 2, 'previousClose': 2653.4731, 'open': 2653.4731, 'dayLow': 2612.5308, 'dayHigh': 2668.608, 'regularMarketPreviousClose': 2653.4731, 'regularMarketOpen': 2653.4731, 'regularMarketDayLow': 2612.5308, 'regularMarketDayHigh': 2668.608, 'volume': 15584092160, 'regularMarketVolume': 15584092160, 'averageVolume': 15762256357, 'averageVolume10days': 15859042188, 'averageDailyVolume10Day': 15859042188, 'marketCap': 314875052032, 'fiftyTwoWeekLow': 1523.2375, 'fiftyTwoWeekHigh': 4092.2842, 'fiftyDayAverage': 25
# ...

# %% [markdown]
# ## Acciones y cedears

# %%
import yfinance as yf

# Definir el ticker para BYMA
# Nota: Reemplaza 'AAPL.BA' con el ticker correcto para BYMA si es diferente
ticker = yf.Ticker("IBM")

# Obtener datos históricos
historical_data = ticker.history(period="1mo", interval="15m")
print("Datos históricos:")
print(historical_data)
# Out:
# Datos históricos:
#                                  Open        High         Low       Close  \
# Datetime
# 2024-08-28 09:30:00-04:00  199.000000  199.020004  198.500000  198.779999
# 2024-08-28 09:45:00-04:00  198.779999  199.970001  198.759995  199.623199
# 2024-08-28 10:00:00-04:00  199.630005  199.774994  199.259995  199.720001
# 2024-08-28 10:15:00-04:00  199.750000  200.000000  199.475006  199.565002
# 2024-08-28 10:30:00-04:00  199.565002  199.770004  199.369995  199.419998
# ...                               ...         ...         ...         ...
# 2024-09-27 14:45:00-04:00  221.770004  221.979996  221.669998  221.839996
# 2024-09-27 15:00:00-04:00  221.889999  221.947495  221.419998  221.429993
# 2024-09-27 15:15:00-04:00  221.449997  221.619904  221.110001  221.460007
# 2024-09-27 15:30:00-04:00  221.429993  221.460007  221.070007  221.179993
# 2024-09-27 15:45:00-04:00  221.175003  221.410004  220.770004  220.789993
#
# ...

# %% [markdown]
# ## Critomonedas

# %%
btc = yf.Ticker("ibm")
btc_data = btc.history(period="5d")
print(btc_data)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-09-10 00:00:00-04:00  204.199997  205.830002  202.869995  205.320007
# 2024-09-11 00:00:00-04:00  207.759995  210.119995  203.039993  209.889999
# 2024-09-12 00:00:00-04:00  210.000000  212.649994  208.270004  211.610001
# 2024-09-13 00:00:00-04:00  212.479996  216.089996  212.130005  214.789993
# 2024-09-16 00:00:00-04:00  215.880005  217.899994  215.520004  216.475006
#
#                             Volume  Dividends  Stock Splits
# Date
# 2024-09-10 00:00:00-04:00  3070600        0.0           0.0
# 2024-09-11 00:00:00-04:00  5554300        0.0           0.0
# 2024-09-12 00:00:00-04:00  4616400        0.0           0.0
# 2024-09-13 00:00:00-04:00  4571600        0.0           0.0
# 2024-09-16 00:00:00-04:00  1084030        0.0           0.0

# %% [markdown]
# ## Indices

# %%
import yfinance as yf
sp500 = yf.Ticker("^GSPC")
sp500_data = sp500.history(period="5d")

print(sp500_data)
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2024-10-16 00:00:00-04:00  5816.580078  5846.520020  5808.339844  5842.470215
# 2024-10-17 00:00:00-04:00  5875.620117  5878.459961  5840.250000  5841.470215
# 2024-10-18 00:00:00-04:00  5859.430176  5872.169922  5846.109863  5864.669922
# 2024-10-21 00:00:00-04:00  5857.819824  5866.919922  5824.790039  5853.979980
# 2024-10-22 00:00:00-04:00  5832.700195  5863.040039  5821.169922  5851.200195
#
#                                Volume  Dividends  Stock Splits
# Date
# 2024-10-16 00:00:00-04:00  3467230000        0.0           0.0
# 2024-10-17 00:00:00-04:00  3480010000        0.0           0.0
# 2024-10-18 00:00:00-04:00  3374490000        0.0           0.0
# 2024-10-21 00:00:00-04:00  3407010000        0.0           0.0
# 2024-10-22 00:00:00-04:00  2197129000        0.0           0.0

# %% [markdown]
# ## Forex

# %%
eur = yf.Ticker("EURUSD=X") # Petroleo
eur_data = eur.history(period="5d")

# %% [markdown]
# ## Comodities

# %%
gold = yf.Ticker("GC=F") # Oro
gold_data = gold.info

pet = yf.Ticker("CL=F") # Petroleo
pet_data = pet.history(period="5d")

azu = yf.Ticker("SB=F") # Azucar
azu__data = azu.history(period="5d")

print(gold_data)
# Out:
# {'maxAge': 86400, 'priceHint': 2, 'previousClose': 2738.9, 'open': 2734.7, 'dayLow': 2733.5, 'dayHigh': 2763.2, 'regularMarketPreviousClose': 2738.9, 'regularMarketOpen': 2734.7, 'regularMarketDayLow': 2733.5, 'regularMarketDayHigh': 2763.2, 'volume': 161954, 'regularMarketVolume': 161954, 'averageVolume': 3004, 'averageVolume10days': 134, 'averageDailyVolume10Day': 134, 'bid': 2762.3, 'ask': 2762.4, 'bidSize': 1400, 'askSize': 800, 'expireDate': 1735257600, 'openInterest': 447540, 'fiftyTwoWeekLow': 1932.6, 'fiftyTwoWeekHigh': 2763.2, 'fiftyDayAverage': 2574.258, 'twoHundredDayAverage': 2328.2905, 'currency': 'USD', 'exchange': 'CMX', 'quoteType': 'FUTURE', 'symbol': 'GCZ24.CMX', 'underlyingSymbol': 'GC=F', 'shortName': 'Gold Dec 24', 'firstTradeDateEpochUtc': 967608000, 'timeZoneFullName': 'America/New_York', 'timeZoneShortName': 'EDT', 'uuid': '14f8f2ec-b820-38f7-ba5f-b3f5a47aec05', 'gmtOffSetMilliseconds': -14400000, 'trailingPegRatio': None}

# %% [markdown]
# # Alphadvantage
# ## Noticias

# %%
import requests
import json

with open('secret.json', 'r') as file:
    secrets = json.load(file)

api_key_alpha= secrets.get('api_key_alpha')


# Símbolo del S&P 500 (índice)
symbol = 'IBM'

url = f'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers={symbol}&apikey={api_key_alpha}'

response = requests.get(url)
data = response.json()

# Mostramos los datos del S&P 500
print(data)
# Out:
# {'items': '50', 'sentiment_score_definition': 'x <= -0.35: Bearish; -0.35 < x <= -0.15: Somewhat-Bearish; -0.15 < x < 0.15: Neutral; 0.15 <= x < 0.35: Somewhat_Bullish; x >= 0.35: Bullish', 'relevance_score_definition': '0 < x <= 1, with a higher score indicating higher relevance.', 'feed': [{'title': 'ServiceNow Rises 6% in a Month: Should Investors Buy NOW Stock?', 'url': 'https://www.zacks.com/stock/news/2337952/servicenow-rises-6-in-a-month-should-investors-buy-now-stock', 'time_published': '20240918T144900', 'authors': ['Aniruddha Ganguly'], 'summary': 'NOW is an attractive stock for growth-oriented investors, given its portfolio strength, growing GenAI prowess and strong partner base.', 'banner_image': 'https://staticx-tuner.zacks.com/images/articles/main/58/2932.jpg', 'source': 'Zacks Commentary', 'category_within_source': 'n/a', 'source_domain': 'www.zacks.com', 'topics': [{'topic': 'Financial Markets', 'relevance_score': '0.214378'}, {'topic': 'Manufacturing', 'relevance_sco
# ...

# %% [markdown]
# ## Acciones y cedears

# %%
# Diario
#url = "https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=IBM&outputsize=full&apikey=demo"

# Intraday
url = "https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=BTC&interval=5min&outputsize=full&apikey=4ZKIOOXWRATHTS84"

response = requests.get(url)
data = response.json()

# Mostramos los datos del S&P 500
print(data)
# Out:
# {'Meta Data': {'1. Information': 'Intraday (5min) open, high, low, close prices and volume', '2. Symbol': 'BTC', '3. Last Refreshed': '2024-09-27 20:00:00', '4. Interval': '5min', '5. Output Size': 'Full size', '6. Time Zone': 'US/Eastern'}, 'Time Series (5min)': {'2024-09-27 20:00:00': {'1. open': '5.8200', '2. high': '5.8200', '3. low': '5.8200', '4. close': '5.8200', '5. volume': '1776'}, '2024-09-27 19:55:00': {'1. open': '5.8800', '2. high': '5.8800', '3. low': '5.8800', '4. close': '5.8800', '5. volume': '3'}, '2024-09-27 19:50:00': {'1. open': '5.8300', '2. high': '5.8300', '3. low': '5.8300', '4. close': '5.8300', '5. volume': '100'}, '2024-09-27 19:40:00': {'1. open': '5.8900', '2. high': '5.8900', '3. low': '5.8900', '4. close': '5.8900', '5. volume': '400'}, '2024-09-27 19:35:00': {'1. open': '5.8900', '2. high': '5.8900', '3. low': '5.8900', '4. close': '5.8900', '5. volume': '102'}, '2024-09-27 19:15:00': {'1. open': '5.8894', '2. high': '5.8894', '3. low': '5.8894', '4.
# ...

# %% [markdown]
# ## Informacion

# %%
import requests

# info numerica
url = 'https://www.alphavantage.co/query?function=OVERVIEW&symbol=NVDA&apikey=FKKQVSU1ZB1XK97Y'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'Symbol': 'NVDA', 'AssetType': 'Common Stock', 'Name': 'NVIDIA Corporation', 'Description': 'Nvidia Corporation is an American multinational technology company incorporated in Delaware and based in Santa Clara, California. It designs graphics processing units (GPUs) for the gaming and professional markets, as well as system on a chip units (SoCs) for the mobile computing and automotive market.', 'CIK': '1045810', 'Exchange': 'NASDAQ', 'Currency': 'USD', 'Country': 'USA', 'Sector': 'MANUFACTURING', 'Industry': 'SEMICONDUCTORS & RELATED DEVICES', 'Address': '2701 SAN TOMAS EXPRESSWAY, SANTA CLARA, CA, US', 'OfficialSite': 'https://www.nvidia.com', 'FiscalYearEnd': 'January', 'LatestQuarter': '2024-07-31', 'MarketCapitalization': '2891351065000', 'EBITDA': '61184000000', 'PERatio': '55.34', 'PEGRatio': '1.219', 'BookValue': '2.368', 'DividendPerShare': '0.022', 'DividendYield': '0.0003', 'EPS': '2.13', 'RevenuePerShareTTM': '3.91', 'ProfitMargin': '0.55', 'OperatingMarginTTM': '0.621',
# ...

# %%
import requests

# balances
url = 'https://www.alphavantage.co/query?function=BALANCE_SHEET&symbol=IBM&apikey=demo'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'symbol': 'IBM', 'annualReports': [{'fiscalDateEnding': '2023-12-31', 'reportedCurrency': 'USD', 'totalAssets': '135241000000', 'totalCurrentAssets': '32908000000', 'cashAndCashEquivalentsAtCarryingValue': '13068000000', 'cashAndShortTermInvestments': '13068000000', 'inventory': '1161000000', 'currentNetReceivables': '7725000000', 'totalNonCurrentAssets': '101302000000', 'propertyPlantEquipment': '-472000000', 'accumulatedDepreciationAmortizationPPE': 'None', 'intangibleAssets': '71214000000', 'intangibleAssetsExcludingGoodwill': '11036000000', 'goodwill': '60178000000', 'investments': '125000000', 'longTermInvestments': '125000000', 'shortTermInvestments': '373000000', 'otherCurrentAssets': '2219000000', 'otherNonCurrentAssets': 'None', 'totalLiabilities': '112628000000', 'totalCurrentLiabilities': '34122000000', 'currentAccountsPayable': '4132000000', 'deferredRevenue': '16984000000', 'currentDebt': '12851000000', 'shortTermDebt': '6426000000', 'totalNonCurrentLiabilities': '87072
# ...

# %%
import requests

# earnings
url = 'https://www.alphavantage.co/query?function=EARNINGS&symbol=IBM&apikey=demo'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'symbol': 'IBM', 'annualEarnings': [{'fiscalDateEnding': '2024-06-30', 'reportedEPS': '4.11'}, {'fiscalDateEnding': '2023-12-31', 'reportedEPS': '9.61'}, {'fiscalDateEnding': '2022-12-31', 'reportedEPS': '9.12'}, {'fiscalDateEnding': '2021-12-31', 'reportedEPS': '9.97'}, {'fiscalDateEnding': '2020-12-31', 'reportedEPS': '8.67'}, {'fiscalDateEnding': '2019-12-31', 'reportedEPS': '12.81'}, {'fiscalDateEnding': '2018-12-31', 'reportedEPS': '13.82'}, {'fiscalDateEnding': '2017-12-31', 'reportedEPS': '13.65'}, {'fiscalDateEnding': '2016-12-31', 'reportedEPS': '13.6'}, {'fiscalDateEnding': '2015-12-31', 'reportedEPS': '14.93'}, {'fiscalDateEnding': '2014-12-31', 'reportedEPS': '16.27'}, {'fiscalDateEnding': '2013-12-31', 'reportedEPS': '17.03'}, {'fiscalDateEnding': '2012-12-31', 'reportedEPS': '15.3'}, {'fiscalDateEnding': '2011-12-31', 'reportedEPS': '13.49'}, {'fiscalDateEnding': '2010-12-31', 'reportedEPS': '11.58'}, {'fiscalDateEnding': '2009-12-31', 'reportedEPS': '10.01'}, {'fiscal
# ...

# %%
import requests

# cash flow
url = 'https://www.alphavantage.co/query?function=CASH_FLOW&symbol=IBM&apikey=demo'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'symbol': 'IBM', 'annualReports': [{'fiscalDateEnding': '2023-12-31', 'reportedCurrency': 'USD', 'operatingCashflow': '13931000000', 'paymentsForOperatingActivities': '2645000000', 'proceedsFromOperatingActivities': 'None', 'changeInOperatingLiabilities': '65000000', 'changeInOperatingAssets': '-1115000000', 'depreciationDepletionAndAmortization': '4396000000', 'capitalExpenditures': '1245000000', 'changeInReceivables': '-725000000', 'changeInInventory': '-390000000', 'profitLoss': '7523000000', 'cashflowFromInvestment': '-7070000000', 'cashflowFromFinancing': '-1769000000', 'proceedsFromRepaymentsOfShortTermDebt': '-7000000', 'paymentsForRepurchaseOfCommonStock': 'None', 'paymentsForRepurchaseOfEquity': 'None', 'paymentsForRepurchaseOfPreferredStock': 'None', 'dividendPayout': '6040000000', 'dividendPayoutCommonStock': '6040000000', 'dividendPayoutPreferredStock': 'None', 'proceedsFromIssuanceOfCommonStock': 'None', 'proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet': '9586
# ...

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=SMA&symbol=IBM&interval=weekly&time_period=10&series_type=open&apikey=demo'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'Meta Data': {'1: Symbol': 'IBM', '2: Indicator': 'Simple Moving Average (SMA)', '3: Last Refreshed': '2024-09-18', '4: Interval': 'weekly', '5: Time Period': 10, '6: Series Type': 'open', '7: Time Zone': 'US/Eastern'}, 'Technical Analysis: SMA': {'2024-09-18': {'SMA': '193.8892'}, '2024-09-13': {'SMA': '189.7896'}, '2024-09-06': {'SMA': '186.7906'}, '2024-08-30': {'SMA': '183.9483'}, '2024-08-23': {'SMA': '181.0784'}, '2024-08-16': {'SMA': '178.5028'}, '2024-08-09': {'SMA': '175.8877'}, '2024-08-02': {'SMA': '174.4889'}, '2024-07-26': {'SMA': '172.0919'}, '2024-07-19': {'SMA': '170.5156'}, '2024-07-12': {'SMA': '168.6781'}, '2024-07-05': {'SMA': '167.6198'}, '2024-06-28': {'SMA': '168.3322'}, '2024-06-21': {'SMA': '169.1971'}, '2024-06-14': {'SMA': '171.0409'}, '2024-06-07': {'SMA': '172.8809'}, '2024-05-31': {'SMA': '175.0448'}, '2024-05-24': {'SMA': '176.9634'}, '2024-05-17': {'SMA': '179.3576'}, '2024-05-10': {'SMA': '181.1809'}, '2024-05-03': {'SMA': '183.0556'}, '2024-04-26': 
# ...

# %% [markdown]
# ## Commodities

# %%
import requests

url = 'https://www.alphavantage.co/query?function=SUGAR&interval=monthly&apikey=demo'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'name': 'Global Price of Sugar', 'interval': 'monthly', 'unit': 'cents per pound', 'data': [{'date': '2024-07-01', 'value': '19.3517391304348'}, {'date': '2024-06-01', 'value': '19.1695'}, {'date': '2024-05-01', 'value': '18.7995652173913'}, {'date': '2024-04-01', 'value': '20.6472727272727'}, {'date': '2024-03-01', 'value': '21.7690476190476'}, {'date': '2024-02-01', 'value': '23.3419047619048'}, {'date': '2024-01-01', 'value': '22.4747826086957'}, {'date': '2023-12-01', 'value': '22.1457142857143'}, {'date': '2023-11-01', 'value': '27.3095454545455'}, {'date': '2023-10-01', 'value': '26.9036363636364'}, {'date': '2023-09-01', 'value': '26.5638095238095'}, {'date': '2023-08-01', 'value': '24.1930434782609'}, {'date': '2023-07-01', 'value': '24.0080952380952'}, {'date': '2023-06-01', 'value': '24.7622727272727'}, {'date': '2023-05-01', 'value': '25.7295652173913'}, {'date': '2023-04-01', 'value': '24.582'}, {'date': '2023-03-01', 'value': '20.9617391304348'}, {'date': '2023-02-01', 
# ...

# %% [markdown]
# ## Binance
# # Obtener todas las criptomonedas

# %%
from binance.client import Client
import json

with open('secret.json', 'r') as file:
    secrets = json.load(file)
api_key= secrets.get('api_key')
api_secret = secrets.get('api_secret')

client = Client(api_key=api_key, api_secret=api_secret)

exchange_info = client.get_exchange_info()
symbols = [s['symbol'] for s in exchange_info['symbols']]

print("Available symbols:")
for symbol in symbols:
    print(symbol)

# %% [markdown]
# ## Binance
# # Futuros

# %%
futures_price = client.futures_ticker(symbol="BTCUSDT")
print(futures_price)
# Out:
# {'symbol': 'BTCUSDT', 'priceChange': '2096.10', 'priceChangePercent': '3.899', 'weightedAvgPrice': '54989.59', 'lastPrice': '55855.50', 'lastQty': '0.122', 'openPrice': '53759.40', 'highPrice': '55886.90', 'lowPrice': '53661.40', 'volume': '250358.633', 'quoteVolume': '13767118531.94', 'openTime': 1725811920000, 'closeTime': 1725898367952, 'firstId': 5364028318, 'lastId': 5367176468, 'count': 3148140}

# %% [markdown]
# ## Binance
# # Margin Trading

# %%
btc_up_price = client.get_symbol_ticker(symbol="BTCUPUSDT")
print(btc_up_price)

# Obtener el precio de BTCDOWN/USDT
btc_down_price = client.get_symbol_ticker(symbol="BTCDOWNUSDT")
print(btc_down_price)
# Out:
# {'symbol': 'BTCUPUSDT', 'price': '16.60000000'}
# {'symbol': 'BTCDOWNUSDT', 'price': '0.00118500'}

# %% [markdown]
# ## Coingeko

# %%
import requests

url = 'https://api.coingecko.com/api/v3/coins/markets'
params = {
    'vs_currency': 'usd',
    'order': 'market_cap_desc',
    'per_page': 10,
    'page': 1,
    'sparkline': 'false'
}

response = requests.get(url, params=params)
cryptos = response.json()

for crypto in cryptos:
    print(crypto['id'], crypto['symbol'], crypto['current_price'])
# Out:
# bitcoin btc 55506
# ethereum eth 2297.99
# tether usdt 1.001
# binancecoin bnb 507.16
# solana sol 128.7
# usd-coin usdc 1.001
# ripple xrp 0.530341
# staked-ether steth 2295.0
# dogecoin doge 0.099126
# tron trx 0.154686

# %%
import requests

def obtener_datos_cripto(crypto_id):
    url = f'https://api.coingecko.com/api/v3/coins/{crypto_id}'
    response = requests.get(url)
    data = response.json()
    return data

# Obtener información sobre Bitcoin
bitcoin_data = obtener_datos_cripto('bitcoin')
print(bitcoin_data)
# Out:
# {'id': 'bitcoin', 'symbol': 'btc', 'name': 'Bitcoin', 'web_slug': 'bitcoin', 'asset_platform_id': None, 'platforms': {'': ''}, 'detail_platforms': {'': {'decimal_place': None, 'contract_address': ''}}, 'block_time_in_minutes': 10, 'hashing_algorithm': 'SHA-256', 'categories': ['Cryptocurrency', 'Layer 1 (L1)', 'FTX Holdings', 'Proof of Work (PoW)', 'GMCI 30 Index'], 'preview_listing': False, 'public_notice': None, 'additional_notices': [], 'localization': {'en': 'Bitcoin', 'de': 'Bitcoin', 'es': 'Bitcoin', 'fr': 'Bitcoin', 'it': 'Bitcoin', 'pl': 'Bitcoin', 'ro': 'Bitcoin', 'hu': 'Bitcoin', 'nl': 'Bitcoin', 'pt': 'Bitcoin', 'sv': '', 'vi': 'Bitcoin', 'tr': 'Bitcoin', 'ru': 'Биткоин', 'ja': 'ビットコイン', 'zh': '比特币', 'zh-tw': '比特幣', 'ko': '비트코인', 'ar': 'بيتكوين', 'th': 'บิตคอยน์', 'id': 'Bitcoin', 'cs': '', 'da': '', 'el': '', 'hi': '', 'no': '', 'sk': '', 'uk': 'Bitcoin', 'he': '', 'fi': '', 'bg': '', 'hr': '', 'lt': '', 'sl': ''}, 'description': {'en': 'Bitcoin is the first successful in
# ...

# %% [markdown]
# ## Criptocompare

# %%
import requests

# URL de la API de CryptoCompare para obtener información de Bitcoin
url = 'https://min-api.cryptocompare.com/data/price'
params = {
    'fsym': 'BTC',
    'tsyms': 'USD'
}

response = requests.get(url, params=params)
bitcoin_price = response.json()

print(bitcoin_price)
# Out:
# {'USD': 56655.75}

# %% [markdown]
# # POLYGON
# ## NOTICIAS

# %%
import requests, json

with open('secret.json', 'r') as file:
    secrets = json.load(file)

api_key_poligon = secrets.get('api_key_poligon')

#activo = "BTC-USD".split('-')[0]
activo = "tsla"

url = f"https://api.polygon.io/v2/reference/news?ticker={activo}&limit=10&apiKey={api_key_poligon}"

response = requests.get(url)
data = response.json()

print(data)
# Out:
# {'results': [{'id': '2b513722fa7ad1d7d43f91717cbd84e1d0778fab4926df628014e4f21e8de2f9', 'publisher': {'name': 'Benzinga', 'homepage_url': 'https://www.benzinga.com/', 'logo_url': 'https://s3.polygon.io/public/assets/news/logos/benzinga.svg', 'favicon_url': 'https://s3.polygon.io/public/assets/news/favicons/benzinga.ico'}, 'title': "Analyst Predicts Energized Crypto Market After Fed's Decision: Says Bitcoin, Ethereum, And DeFi Set To Rally Amid Anticipation Of Further Rate Cuts: 'The Bull Market Has Started'", 'author': 'Benzinga Neuro, Benzinga Staff Writer', 'published_utc': '2024-09-19T10:07:40Z', 'article_url': 'https://www.benzinga.com/analyst-ratings/analyst-color/24/09/40934438/analyst-predicts-energized-crypto-market-after-feds-decision-says-bitcoin-ethereum-', 'tickers': ['BTC', 'DEFG', 'ETHV'], 'image_url': 'https://cdn.benzinga.com/files/images/story/2024/09/19/Bitcoins-Quick-Recovery.jpeg?width=1200&height=800&fit=crop', 'description': "Analyst Michaël van de Poppe is bull
# ...

# %% [markdown]
# ## INFORMACIÓN

# %%
import requests, json

with open('secret.json', 'r') as file:
    secrets = json.load(file)

api_key_poligon = secrets.get('api_key_poligon')

#activo = "BTC-USD".split('-')[0]
activo = "IBM"

url = f"https://api.polygon.io/v2/reference/news?ticker={activo}&limit=10&apiKey={api_key_poligon}"

response = requests.get(url)
data = response.json()

print(data)
# Out:
# {'results': [{'id': '32546f103195c971d57c8db439de02775fc5a91620a0185e6de8b1192909e125', 'publisher': {'name': 'GlobeNewswire Inc.', 'homepage_url': 'https://www.globenewswire.com', 'logo_url': 'https://s3.polygon.io/public/assets/news/logos/globenewswire.svg', 'favicon_url': 'https://s3.polygon.io/public/assets/news/favicons/globenewswire.ico'}, 'title': 'Saudi Arabia Industry 4.0 Research Report 2024: Competition, Forecast & Opportunities, 2029F', 'author': 'Globe Newswire', 'published_utc': '2024-09-20T10:51:00Z', 'article_url': 'https://www.globenewswire.com/news-release/2024/09/20/2949585/28124/en/Saudi-Arabia-Industry-4-0-Research-Report-2024-Competition-Forecast-Opportunities-2029F.html', 'tickers': ['SIEGY', 'SBGSY', 'HON', 'YOKEY', 'IBM', 'CSCO', 'ROK', 'ABBNY'], 'image_url': 'https://ml.globenewswire.com/Resource/Download/908fb457-7f8e-4a08-9081-5565e3dfb3d7', 'description': 'The Saudi Arabia Industry 4.0 market is expected to grow significantly at a CAGR of 13.3% from 2023 
# ...

# %%
import requests

url = "https://api.mymemory.translated.net/get"
params = {
  "q": "Could Investing $10,000 in Solana Make You a Millionaire?",
  "langpair": "en|es"
}
response = requests.get(url, params=params)
print(response.json()['responseData']['translatedText'])
# Out:
# ¿Invertir $ 10.000 en Solana podría hacerte millonario?

# %%
import yfinance as yf

# Define el ticker y el intervalo
ticker = "BTC-USD"  # Cambia esto por el símbolo que desees
period = "1d"    # Utiliza '1d' para un día de datos
interval = "1d"  # Intervalo de 5 minutos

# Obtener los datos del historial
stock_data = yf.Ticker(ticker)
history = stock_data.history(period=period, interval=interval)

# Verifica si obtuviste datos
if history.empty:
    print("No se encontraron datos con el intervalo seleccionado.")
else:
    print(history)
# Out:
#                                    Open          High           Low  \
# Date
# 2024-09-20 00:00:00+00:00  62958.390625  64059.882812  62401.566406
#
#                                   Close       Volume  Dividends  Stock Splits
# Date
# 2024-09-20 00:00:00+00:00  63176.226562  35253719040        0.0           0.0
